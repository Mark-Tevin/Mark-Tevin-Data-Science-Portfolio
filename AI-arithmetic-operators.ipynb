# %% [markdown]
# <a href="https://www.kaggle.com/code/marktevin/ai-arithmetic-operators?scriptVersionId=349332607" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # AI Programming: Arithmetic Operators, Model Performance & Data Storage
#
# ## Overview
#
# This notebook contains practical Python exercises from my AI Programming learning journey through the **AWS AI & ML Scholars Program**.
#
# The exercises introduce AI concepts related to evaluating model performance and managing data storage.
#
# The focus is on applying Python arithmetic operators, basic statistical calculations, and data storage calculations to practical AI/ML scenarios. Although the exercises begin with simple arithmetic, the underlying concepts are important building blocks for more advanced work in projects:
#
# These exercises help to:
#
# Apply Statistical Measures: Calculating averages is essential in analyzing performance metrics of models.
# Plan Data Storage: Understanding the storage requirements and planning accordingly is crucial for handling large datasets in AI projects.
# ## Learning Objectives
#
# By completing these exercises, I aim to develop a stronger understanding of how Python can be used to solve practical problems in AI and Machine Learning.
#
# Specifically, I will practice how to:
#
# * Use Python arithmetic operators to solve quantitative problems.
# * Calculate averages and interpret numerical results.
# * Understand the basic concept of model prediction accuracy.
# * Calculate storage requirements for machine learning datasets.
# * Convert storage units between KB and MB.
# * Determine available storage capacity after storing datasets.
# * Translate real-world scenarios into Python expressions and calculations.
# * Present technical results in a clear and understandable format.
#
# ## 1. Evaluating Model Performance
#
# ### Understanding Model Accuracy
#
# In Machine Learning, a model is trained to make predictions based on data. After training, we need to evaluate how well the model performs.
#
# One common metric used in classification problems is **accuracy**.
#
# Accuracy measures the proportion of predictions that are correct out of the total number of predictions. This involves basic statistics, such as mean and percentage calculations.
#
# The general formula is:
#
# $$
# \text{Accuracy} =
# \frac{\text{Number of Correct Predictions}}
# {\text{Total Number of Predictions}}
# \times 100
# $$
#
# For example, if a model makes 100 predictions and 85 are correct, its accuracy is:
#
# $$
# \frac{85}{100} \times 100 = 85\%
# $$
#
# ### Why Accuracy Matters
# Accuracy provides a simple way to understand model performance. When evaluating a model over multiple periods or experiments, calculating the average accuracy can help summarize its performance.
#
# However, accuracy is not always sufficient on its own. In real-world ML projects, other metrics such as precision, recall, and F1-score may also be important, especially when dealing with imbalanced datasets.
#
# ### What This Exercise Demonstrates
#
# In this exercise, I will use Python to:
#
# 1. Store accuracy scores for three months.
# 2. Calculate the mean prediction accuracy.
# 3. Format the result as a percentage.
# 4. Interpret the calculated average.
#
# Evaluating Model Performance
# Accuracy Calculation
# It's important to know how to compute and interpret model accuracy to assess how well your model is performing. This involves basic statistics, such as mean and percentage calculations.
#
# Performance Metrics
# Understanding different metrics (accuracy in this case) and how to aggregate them over time gives you a better picture of model performance.
#
# ## 2. Managing Data Storage for Machine Learning Projects
#
# ### Understanding Dataset Storage
#
# Machine Learning projects depend on data. Depending on the application, datasets may contain thousands or millions of images, documents, audio files, or other forms of information.
#
# Before storing or processing these datasets, it is important to understand how much storage they require.
#
# For example, an image classification project may contain thousands of training images. If each image has a known file size, we can calculate the total storage requirement using Python.
#
# ### Why Data Storage Matters
#
# Understanding storage requirements helps with:
#
# * Dataset management
# * Storage capacity planning
# * Cloud infrastructure decisions
# * Resource optimization
# * Machine Learning pipeline preparation
#
# In cloud-based AI environments such as AWS, these calculations provide a foundation for understanding storage services and infrastructure costs.
#
# ### What This Exercise Demonstrates
#
# In this exercise, I will use Python to:
#
# 1. Determine the total number of images across two datasets.
# 2. Calculate the total storage required in KB.
# 3. Convert the storage requirement into MB.
# 4. Compare the required storage with the capacity of a storage device.
# 5. Calculate the remaining available storage.
#
# Data Storage and Management
# Dataset Size Calculation
# Determining the total storage requirements by summing the sizes of different datasets helps you plan the storage resources.
#
# Storage Optimization
# Knowing how much storage is left after accommodating new datasets helps in efficient resource management.
#
# Data Handling
# Being able to handle data efficiently, both in terms of computational processing and storage, is key in any AI project.
#
# ## 3. Connection to AI and Machine Learning Workflows
#
# These exercises demonstrate how basic Python programming and arithmetic can support different stages of an AI/ML workflow.
#
# | AI/ML Area         | Connection to This Exercise                          |
# | ------------------ | ---------------------------------------------------- |
# | Model Evaluation   | Calculating and summarizing prediction accuracy      |
# | Data Science       | Applying averages and numerical analysis             |
# | Dataset Management | Estimating storage requirements                      |
# | Cloud Computing    | Understanding storage capacity and resource planning |
# | Python Programming | Translating practical problems into executable code  |
# | AI Infrastructure  | Supporting basic resource estimation                 |
#
# The calculations in this notebook are introductory. They do not involve training a machine learning model or deploying a cloud infrastructure system. Instead, they establish foundational skills that can be applied in more advanced projects.
#
# ---
#
# ## 4. Expected Learning Outcomes
#
# After completing this notebook, I should be able to:
#
# * Explain the basic meaning of model accuracy.
# * Calculate a mean using Python.
# * Apply arithmetic operators to real-world scenarios.
# * Calculate dataset storage requirements.
# * Convert between storage units.
# * Explain why resource planning matters in AI/ML.
# * Write and document simple Python solutions.
#
# ---
#
# ## 5. Exercises
#
# The notebook contains the following practical exercises:
#
# ### Quiz 1: Evaluating Model Performance
#
# Calculate the average prediction accuracy of a machine learning model over three months.
#
# ### Quiz 2: Managing Data Storage
#
# Calculate the storage requirements of two image datasets and determine the remaining capacity of a storage device.
#
# **Learning by building, documenting, and applying.**

# %% [markdown]
# ## Quiz 1: Evaluating Model Performance
# ### Scenario:
# You are working on a project where you need to analyze the average prediction accuracy of a machine learning model over the last three months. The accuracy scores for the last three months are 85.5%, 90.2%, and 87.3%.
#
# ### Task:
# Write an expression to calculate the mean prediction accuracy over these three months.

# %%
# Accuracy scores for the last three months
accuracy_scores = [85.5, 90.2, 87.3]

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print(f"The average prediction accuracy over the last three months is {average_accuracy:.2f}%")
# Out:
# The average prediction accuracy over the last three months is 87.67%

# %% [markdown]
# ## Quiz 2: Managing Data Storage for Machine Learning Projects
# ### Scenario:
# You are optimizing the data storage for a machine learning project. You have two datasets of image files for training. One dataset contains 4000 images, and the other contains 3000 images. Each image is 256KB in size. Additionally, you receive a new storage device with 2048MB capacity.
#
# ### Tasks:
#
# 1. Calculate the total storage needed for both datasets in MB.
# 2. Determine how much storage will be left after storing all images on the new device in MB.

# %%
# Sizes of datasets (in images)
dataset1_size = 4000
dataset2_size = 3000

# Size of each image in KB
image_size_kb = 256

# Calculate total storage needed (in KB)
total_storage_kb = (dataset1_size + dataset2_size) * image_size_kb

# Convert total storage needed to MB
total_storage_mb = total_storage_kb / 1024
print(f"Total storage needed: {total_storage_mb:.2f} MB")

# Storage device capacity (in MB)
device_capacity_mb = 2048

# Calculate leftover storage in MB
leftover_storage_mb = device_capacity_mb - total_storage_mb
print(f"Storage left after storing all images: {leftover_storage_mb:.2f} MB")
# Out:
# Total storage needed: 1750.00 MB
# Storage left after storing all images: 298.00 MB
